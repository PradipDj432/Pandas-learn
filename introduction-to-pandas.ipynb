# %%
import pandas as pd

# %% [markdown]
# # Type of datatype in pandas

# %% [markdown]
# # 2 type

# %%
# series = 1 - dimensional
car = pd.Series(["Odi","BMW","TATA"])

# %%
car
# Out:
# 0     Odi
# 1     BMW
# 2    TATA
# dtype: object

# %%
# Dataframe = 2 - dimensional
car_data = pd.DataFrame({"car name" : car , "colour" : ["green","blue","white"]})

# %%
car_data
# Out:
#   car name colour
# 0      Odi  green
# 1      BMW   blue
# 2     TATA  white

# %%
# import csv file 
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# exporting a datafreme
# copy car_sales file to new file create name exported_car_sales
car_sales.to_csv("exported-car-sales.csv")

# %%
# now retrive new csv file
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
# now remove unname colume
car_sales.to_csv("exported-car-sales-new.csv",index = False)

# %%
exported_car_sales_new = pd.read_csv("exported-car-sales-new.csv")
exported_car_sales_new
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Describe data

# %%
# Attribute - not a "()" at end
car_sales.dtypes # dtype - return data type object

# Function - end with "()"
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# here odometer and doors are int datatype whenever price is object
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_price = pd.Series([3000,300,30000,30])
car_price.mean()
# Out:
# 8332.5

# %% [markdown]
# # viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(12)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc && .iloc

## here is iloc inbulid index
animals = pd.Series(["cat","dog","cow","ox","panda"])

# %%
## if we don't allocate index than indexloction ans location both are same 
## iloc==loc
animals.iloc[2]
# Out:
# 'cow'

# %%
animals.loc[2]
# Out:
# 'cow'

# %%
animals
# Out:
# 0      cat
# 1      dog
# 2      cow
# 3       ox
# 4    panda
# dtype: object

# %%
# .loc && .iloc

## here loc we build index over self
animals = pd.Series(["cat","dog","cow","ox","panda"],index=[1,3,5,7,5])

# %%
## even iloc is 0 base indexing
animals.loc[3]
# Out:
# 'dog'

# %%
animals
# Out:
# 1      cat
# 3      dog
# 5      cow
# 7       ox
# 5    panda
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'ox'

# %%
animals.loc[5]
# Out:
# 5      cow
# 5    panda
# dtype: object

# %%
animals.loc[1]
# Out:
# 'cat'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# # Slicing

# %%
animals.iloc[:3]
# Out:
# 1    cat
# 3    dog
# 5    cow
# dtype: object

# %%
animals.loc[:3]
# Out:
# 1    cat
# 3    dog
# dtype: object

# %%
animals.iloc[1:3]
# Out:
# 3    dog
# 5    cow
# dtype: object

# %%
car_sales.iloc[2:5] ## upto index 5
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.loc[2:5] ## including index 5
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %% [markdown]
# # Filtring

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # Cross validation

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Doors"],car_sales["Make"])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
pd.crosstab(car_sales["Colour"],car_sales["Make"])
# Out:
# Make    BMW  Honda  Nissan  Toyota
# Colour
# Black     1      0       0       0
# Blue      0      2       0       1
# Green     0      0       0       1
# Red       0      1       0       0
# White     0      0       2       2

# %% [markdown]
# # Groupby

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Make"]).sum(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW             11179      5
# Honda          188335     12
# Nissan         244695      8
# Toyota         341805     15

# %% [markdown]
# #  Graph

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Make"].dtype
# Out:
# dtype('O')

# %%
car_sales["Doors"].dtype
# Out:
# dtype('int64')

# %%
## non numaric data type no plot create
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 car_sales["Price"].plot()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py:1001, in PlotAccessor.__call__(self, *args, **kwargs)
#     998             label_name = label_kw or data.columns
#     999             data.columns = label_name
# -> 1001 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_matplotlib\core.py:451, in MPLPlot.generate(self)
# ...

# %%
## now we convert numaric datatype (object to numaric)
car_sales["Price"]=car_sales["Price"].replace('[\$\,\.]', '', regex=True).astype(int)

# %%
car_sales ## now looking is good
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating data

# %%
car_sales["Make"].str.lower() ## lower case
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales ## only print not change
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"]=car_sales["Make"].str.lower() ## if we like change is update

# %%
car_sales["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales ## now conver in lower case
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %% [markdown]
# # Missing value

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing ## here missing value
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]
# Out:
# 0    150043.0
# 1     87899.0
# 2         NaN
# 3     11179.0
# 4    213095.0
# 5         NaN
# 6         NaN
# 7         NaN
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
## replace null value is mean of odometer
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing ## not change update
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean()) ## now change is update

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna() ## only view not change is update in datafeame
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing  ## here not change made
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
## missing value is drop
car_sales_missing.dropna(inplace=True) ## cheage is update in datafreame

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
## new datafreame create
car_sales_missing2 = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing2
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
## another datafreame create from old missing2 without null value
car_sales_missing_dropped = car_sales_missing2.dropna()

# %%
## dropped null value datafeame

car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
## new file save in over folder (csv file)
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %% [markdown]
# # Add colume

# %%
## two way 
## Using series
## create one series
seats_colume = pd.Series([4,5,5,5,5])

##new column called seats
car_sales["Seats"] = seats_colume

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  average
# 0  toyota  White         150043      4   400000    4.0      7.5
# 1   honda    Red          87899      4   500000    5.0      9.2
# 2  toyota   Blue          32549      3   700000    5.0      5.0
# 3     bmw  Black          11179      5  2200000    5.0      9.6
# 4  nissan  White         213095      4   350000    5.0      5.8
# 5  toyota  Green          99213      4   450000    NaN      9.9
# 6   honda   Blue          45698      4   750000    NaN      3.6
# 7   honda   Blue          54738      4   700000    NaN      4.1
# 8  toyota  White          60000      4   625000    NaN      8.4
# 9  nissan  White          31600      4   970000    NaN      7.4

# %%
car_sales["Seats"].fillna(4,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  average
# 0  toyota  White         150043      4   400000    4.0      7.5
# 1   honda    Red          87899      4   500000    5.0      9.2
# 2  toyota   Blue          32549      3   700000    5.0      5.0
# 3     bmw  Black          11179      5  2200000    5.0      9.6
# 4  nissan  White         213095      4   350000    5.0      5.8
# 5  toyota  Green          99213      4   450000    4.0      9.9
# 6   honda   Blue          45698      4   750000    4.0      3.6
# 7   honda   Blue          54738      4   700000    4.0      4.1
# 8  toyota  White          60000      4   625000    4.0      8.4
# 9  nissan  White          31600      4   970000    4.0      7.4

# %%
## Using list
fuel_economy = [7.5,9.2,5.0,9.6,5.8,9.9,3.6,4.1,8.4,7.4]
car_sales["average"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  average
# 0  toyota  White         150043      4   400000    4.0      7.5
# 1   honda    Red          87899      4   500000    5.0      9.2
# 2  toyota   Blue          32549      3   700000    5.0      5.0
# 3     bmw  Black          11179      5  2200000    5.0      9.6
# 4  nissan  White         213095      4   350000    5.0      5.8
# 5  toyota  Green          99213      4   450000    4.0      9.9
# 6   honda   Blue          45698      4   750000    4.0      3.6
# 7   honda   Blue          54738      4   700000    4.0      4.1
# 8  toyota  White          60000      4   625000    4.0      8.4
# 9  nissan  White          31600      4   970000    4.0      7.4

# %%
car_sales["total fuel used"] = (car_sales["Odometer (KM)"]/100)*car_sales["average"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  average  \
# 0  toyota  White         150043      4   400000    4.0      7.5
# 1   honda    Red          87899      4   500000    5.0      9.2
# 2  toyota   Blue          32549      3   700000    5.0      5.0
# 3     bmw  Black          11179      5  2200000    5.0      9.6
# 4  nissan  White         213095      4   350000    5.0      5.8
# 5  toyota  Green          99213      4   450000    4.0      9.9
# 6   honda   Blue          45698      4   750000    4.0      3.6
# 7   honda   Blue          54738      4   700000    4.0      4.1
# 8  toyota  White          60000      4   625000    4.0      8.4
# 9  nissan  White          31600      4   970000    4.0      7.4
#
#    total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        12359.510
# 5         9822.087
# 6         1645.128
# 7         2244.258
# 8         5040.000
# 9         2338.400

# %%
car_sales["wheels"]=4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  average  \
# 0  toyota  White         150043      4   400000    4.0      7.5
# 1   honda    Red          87899      4   500000    5.0      9.2
# 2  toyota   Blue          32549      3   700000    5.0      5.0
# 3     bmw  Black          11179      5  2200000    5.0      9.6
# 4  nissan  White         213095      4   350000    5.0      5.8
# 5  toyota  Green          99213      4   450000    4.0      9.9
# 6   honda   Blue          45698      4   750000    4.0      3.6
# 7   honda   Blue          54738      4   700000    4.0      4.1
# 8  toyota  White          60000      4   625000    4.0      8.4
# 9  nissan  White          31600      4   970000    4.0      7.4
#
#    total fuel used  wheels
# 0        11253.225       4
# 1         8086.708       4
# 2         1627.450       4
# 3         1073.184       4
# 4        12359.510       4
# 5         9822.087       4
# 6         1645.128       4
# 7         2244.258       4
# ...

# %% [markdown]
# # Drop column

# %%
car_sales = car_sales.drop("average",axis=1)
## if column than axis = 1
## if row than axis = 0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 0  toyota  White         150043      4   400000    4.0        11253.225
# 1   honda    Red          87899      4   500000    5.0         8086.708
# 2  toyota   Blue          32549      3   700000    5.0         1627.450
# 3     bmw  Black          11179      5  2200000    5.0         1073.184
# 4  nissan  White         213095      4   350000    5.0        12359.510
# 5  toyota  Green          99213      4   450000    4.0         9822.087
# 6   honda   Blue          45698      4   750000    4.0         1645.128
# 7   honda   Blue          54738      4   700000    4.0         2244.258
# 8  toyota  White          60000      4   625000    4.0         5040.000
# 9  nissan  White          31600      4   970000    4.0         2338.400
#
#    wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %% [markdown]
# # Shuffle

# %%
## mix column or change column position
car_sales.sample(frac=0.5)
## now index change you can see
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 1   honda    Red          87899      4   500000    5.0         8086.708
# 0  toyota  White         150043      4   400000    4.0        11253.225
# 3     bmw  Black          11179      5  2200000    5.0         1073.184
# 8  toyota  White          60000      4   625000    4.0         5040.000
# 9  nissan  White          31600      4   970000    4.0         2338.400
#
#    wheels
# 1       4
# 0       4
# 3       4
# 8       4
# 9       4

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 9  nissan  White          31600      4   970000    4.0         2338.400
# 6   honda   Blue          45698      4   750000    4.0         1645.128
# 1   honda    Red          87899      4   500000    5.0         8086.708
# 8  toyota  White          60000      4   625000    4.0         5040.000
# 3     bmw  Black          11179      5  2200000    5.0         1073.184
# 4  nissan  White         213095      4   350000    5.0        12359.510
# 2  toyota   Blue          32549      3   700000    5.0         1627.450
# 7   honda   Blue          54738      4   700000    4.0         2244.258
# 5  toyota  Green          99213      4   450000    4.0         9822.087
# 0  toyota  White         150043      4   400000    4.0        11253.225
#
#    wheels
# 9       4
# 6       4
# 1       4
# 8       4
# 3       4
# 4       4
# 2       4
# 7       4
# 5       4
# 0       4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 0  toyota  White         150043      4   400000    4.0        11253.225
# 1   honda    Red          87899      4   500000    5.0         8086.708
# 2  toyota   Blue          32549      3   700000    5.0         1627.450
# 3     bmw  Black          11179      5  2200000    5.0         1073.184
# 4  nissan  White         213095      4   350000    5.0        12359.510
# 5  toyota  Green          99213      4   450000    4.0         9822.087
# 6   honda   Blue          45698      4   750000    4.0         1645.128
# 7   honda   Blue          54738      4   700000    4.0         2244.258
# 8  toyota  White          60000      4   625000    4.0         5040.000
# 9  nissan  White          31600      4   970000    4.0         2338.400
#
#    wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
car_sales_suffule = car_sales.sample(frac=1)
car_sales_suffule
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 2  toyota   Blue          32549      3   700000    5.0         1627.450
# 5  toyota  Green          99213      4   450000    4.0         9822.087
# 0  toyota  White         150043      4   400000    4.0        11253.225
# 8  toyota  White          60000      4   625000    4.0         5040.000
# 9  nissan  White          31600      4   970000    4.0         2338.400
# 6   honda   Blue          45698      4   750000    4.0         1645.128
# 7   honda   Blue          54738      4   700000    4.0         2244.258
# 1   honda    Red          87899      4   500000    5.0         8086.708
# 3     bmw  Black          11179      5  2200000    5.0         1073.184
# 4  nissan  White         213095      4   350000    5.0        12359.510
#
#    wheels
# 2       4
# 5       4
# 0       4
# 8       4
# 9       4
# 6       4
# 7       4
# 1       4
# 3       4
# 4       4

# %% [markdown]
# # Reset index

# %%
car_sales_suffule.reset_index(inplace=True)

# %%
car_sales_suffule
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0      1   honda    Red          87899      4   500000    5.0
# 1      6   honda   Blue          45698      4   750000    4.0
# 2      9  nissan  White          31600      4   970000    4.0
# 3      7   honda   Blue          54738      4   700000    4.0
# 4      0  toyota  White         150043      4   400000    4.0
# 5      2  toyota   Blue          32549      3   700000    5.0
# 6      5  toyota  Green          99213      4   450000    4.0
# 7      4  nissan  White         213095      4   350000    5.0
# 8      8  toyota  White          60000      4   625000    4.0
# 9      3     bmw  Black          11179      5  2200000    5.0
#
#    total fuel used  wheels
# 0         8086.708       4
# 1         1645.128       4
# 2         2338.400       4
# 3         2244.258       4
# 4        11253.225       4
# 5         1627.450       4
# 6         9822.087       4
# 7        12359.510       4
# 8         5040.000       4
# ...

# %%
## now remove addintion column
car_sales_suffule.reset_index(drop=True,inplace=True)

# %%
car_sales_suffule
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 0  toyota   Blue          32549      3   700000    5.0         1627.450
# 1  toyota  Green          99213      4   450000    4.0         9822.087
# 2  toyota  White         150043      4   400000    4.0        11253.225
# 3  toyota  White          60000      4   625000    4.0         5040.000
# 4  nissan  White          31600      4   970000    4.0         2338.400
# 5   honda   Blue          45698      4   750000    4.0         1645.128
# 6   honda   Blue          54738      4   700000    4.0         2244.258
# 7   honda    Red          87899      4   500000    5.0         8086.708
# 8     bmw  Black          11179      5  2200000    5.0         1073.184
# 9  nissan  White         213095      4   350000    5.0        12359.510
#
#    wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %% [markdown]
# # Change column value

# %%
## simple methoed
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"]/1.6

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 0  toyota  White      93776.875      4   400000    4.0        11253.225
# 1   honda    Red      54936.875      4   500000    5.0         8086.708
# 2  toyota   Blue      20343.125      3   700000    5.0         1627.450
# 3     bmw  Black       6986.875      5  2200000    5.0         1073.184
# 4  nissan  White     133184.375      4   350000    5.0        12359.510
# 5  toyota  Green      62008.125      4   450000    4.0         9822.087
# 6   honda   Blue      28561.250      4   750000    4.0         1645.128
# 7   honda   Blue      34211.250      4   700000    4.0         2244.258
# 8  toyota  White      37500.000      4   625000    4.0         5040.000
# 9  nissan  White      19750.000      4   970000    4.0         2338.400
#
#    wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"]*1.6

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 0  toyota  White       150043.0      4   400000    4.0        11253.225
# 1   honda    Red        87899.0      4   500000    5.0         8086.708
# 2  toyota   Blue        32549.0      3   700000    5.0         1627.450
# 3     bmw  Black        11179.0      5  2200000    5.0         1073.184
# 4  nissan  White       213095.0      4   350000    5.0        12359.510
# 5  toyota  Green        99213.0      4   450000    4.0         9822.087
# 6   honda   Blue        45698.0      4   750000    4.0         1645.128
# 7   honda   Blue        54738.0      4   700000    4.0         2244.258
# 8  toyota  White        60000.0      4   625000    4.0         5040.000
# 9  nissan  White        31600.0      4   970000    4.0         2338.400
#
#    wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4

# %%
## using function
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x : x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  total fuel used  \
# 0  toyota  White      93776.875      4   400000    4.0        11253.225
# 1   honda    Red      54936.875      4   500000    5.0         8086.708
# 2  toyota   Blue      20343.125      3   700000    5.0         1627.450
# 3     bmw  Black       6986.875      5  2200000    5.0         1073.184
# 4  nissan  White     133184.375      4   350000    5.0        12359.510
# 5  toyota  Green      62008.125      4   450000    4.0         9822.087
# 6   honda   Blue      28561.250      4   750000    4.0         1645.128
# 7   honda   Blue      34211.250      4   700000    4.0         2244.258
# 8  toyota  White      37500.000      4   625000    4.0         5040.000
# 9  nissan  White      19750.000      4   970000    4.0         2338.400
#
#    wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# 9       4
